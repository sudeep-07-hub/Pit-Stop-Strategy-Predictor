# %%
import pandas as pd
import fastf1

cache_path = '/Users/sukesh/Desktop/Pit/data'
fastf1.Cache.enable_cache(cache_path)

races = [
    (2023, 'Bahrain',  'R'),
    (2023, 'Italy',    'R'),
    (2023, 'Britain',  'R'),
]

session = [fastf1.get_session(race) for race in races]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 13
#       5 fastf1.Cache.enable_cache(cache_path)
#       7 races = [
#       8     (2023, 'Bahrain',  'R'),
#       9     (2023, 'Italy',    'R'),
#      10     (2023, 'Britain',  'R'),
#      11 ]
# ---> 13 session = [fastf1.get_session(race) for race in races]
#
# TypeError: get_session() missing 1 required positional argument: 'gp'
