# %%
import pandas as pd
import numpy as np
import fastf1

# %%
cache_path = '/Users/sukesh/Desktop/Pit/data'
fastf1.Cache.enable_cache(cache_path)

# %%
races = [
    (2023, 'Bahrain',       'R'),
    (2023, 'Saudi Arabia',  'R'),
    (2023, 'Australia',     'R'),
    (2023, 'Azerbaijan',    'R'),
    (2023, 'Monaco',        'R'),
    (2023, 'Spain',         'R'),
    (2023, 'Britain',       'R'),
    (2023, 'Hungary',       'R'),
    (2023, 'Belgium',       'R'),
    (2023, 'Italy',         'R'),
    (2023, 'Japan',         'R'),
    (2023, 'United States', 'R'),
    (2023, 'Canada',        'R'),
    (2023, 'Austria',       'R'),
    (2023, 'Netherlands',   'R'),
    (2023, 'Singapore',     'R')
]

# %% [raw]
# all_laps = []
#
# for year, gp, session_type in races:
#     session = fastf1.get_session(year, gp, session_type)
#     session.load()
#
#     results = session.results[['Abbreviation','Position']]
#     results.columns = ['Driver','FinalPosition']
#
#     laps = session.laps.copy()
#     laps = laps.pick_quicklaps()
#     laps = laps[(laps['LapNumber'] != 1) & (laps['TrackStatus'] == '1')].copy()
#     laps['LapTimeSeconds'] = laps['LapTime'].dt.total_seconds()
#     laps['LapTimeDelta'] = laps['LapTimeSeconds'] - laps.groupby('Driver')['LapTimeSeconds'].transform('mean')
#     laps['LapsRemaining'] = laps.groupby('Driver')['LapNumber'].transform('max') - laps['LapNumber']
#     laps['Race'] = gp
#     laps = laps.merge(results, on='Driver', how='left')
#     all_laps.append(laps)

# %%
combined = pd.concat(all_laps, ignore_index= True)

print(combined.shape)
print(combined['Race'].value_counts())
# Out:
# (13584, 36)
# Race
# Spain            1081
# Canada           1055
# Hungary          1041
# Austria          1040
# United States     922
# Monaco            893
# Italy             879
# Britain           813
# Saudi Arabia      810
# Bahrain           802
# Singapore         797
# Azerbaijan        793
# Netherlands       739
# Australia         732
# Japan             656
# Belgium           531
# Name: count, dtype: int64

# %%
feature_cols = [
    'LapTimeSeconds',
    'LapTimeDelta', 
    'TyreLife',
    'Position',
    'LapsRemaining'
]

WINDOW_SIZE = 10

# %%
print(combined.shape)
print(combined['FinalPosition'].value_counts().sort_index())
print(combined['FinalPosition'].isna().sum())
# Out:
# (13584, 36)
# FinalPosition
# 1.0     783
# 2.0     785
# 3.0     773
# 4.0     773
# 5.0     773
# 6.0     762
# 7.0     769
# 8.0     754
# 9.0     743
# 10.0    737
# 11.0    729
# 12.0    719
# 13.0    702
# 14.0    716
# 15.0    706
# 16.0    672
# 17.0    595
# 18.0    515
# 19.0    400
# 20.0    178
# Name: count, dtype: int64
# 0

# %%
combined.info()
# Out:
# <class 'fastf1.core.Laps'>
# RangeIndex: 13584 entries, 0 to 13583
# Data columns (total 36 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                13584 non-null  timedelta64[ns]
#  1   Driver              13584 non-null  object
#  2   DriverNumber        13584 non-null  object
#  3   LapTime             13584 non-null  timedelta64[ns]
#  4   LapNumber           13584 non-null  float64
#  5   Stint               13584 non-null  float64
#  6   PitOutTime          14 non-null     timedelta64[ns]
#  7   PitInTime           63 non-null     timedelta64[ns]
#  8   Sector1Time         13584 non-null  timedelta64[ns]
#  9   Sector2Time         13584 non-null  timedelta64[ns]
#  10  Sector3Time         13584 non-null  timedelta64[ns]
#  11  Sector1SessionTime  13552 non-null  timedelta64[ns]
#  12  Sector2SessionTime  13584 non-null  timedelta64[ns]
#  13  Sector3SessionTime  13584 non-null  timedelta64[ns]
#  14  SpeedI1             13584 non-null  float64
#  15  SpeedI2             13584 non-null  float64
#  16  SpeedFL             13521 non-null  float64
#  17  SpeedST             13584 non-null  float64
#  18  IsPersonalBest      13584 non-null  object
#  19  Compound            13584 non-null  object
#  20  TyreLife            13549 non-null  float64
#  21  FreshTyre           13584 non-null  bool
#  22  Team                13584 non-null  object
#  23  LapStartTime        13584 non-null  timedelta64[ns]
#  24  LapStartDate        13584 non-null  datetime64[ns]
#  25  TrackStatus         13584 non-null  object
#  26  Position            13584 non-null  float64
#  27  Deleted             13584 non-null  bool
#  28  DeletedReason       13584 non-null  object
#  29  FastF1Generated     13584 non-null  bool
#  30  IsAccurate          13584 non-null  bool
#  31  LapTimeSeconds      13584 non-null  float64
#  32  LapTimeDelta        13584 non-null  float64
#  33  LapsRemaining       13584 non-null  float64
#  34  Race                13584 non-null  object
#  35  FinalPosition       13584 non-null  float64
# dtypes: bool(4), datetime64[ns](1), float64(12), object(8), timedelta64[ns](11)
# memory usage: 3.4+ MB

# %%
test_races = ['Britain', 'Italy']

test_mask = np.array([
    any(race in test_races for race in [combined.groupby(['Race','Driver']).groups])
])

# %%
sequences = []
targets = []
race_labels = []

for (race, driver), group in combined.groupby(['Race', 'Driver']):
    group = group.sort_values('LapNumber')

    if len(group) < WINDOW_SIZE:
        continue

    window = group.iloc[:WINDOW_SIZE][feature_cols].values

    target = group['FinalPosition'].iloc[0]

    sequences.append(window)
    targets.append(target)
    race_labels.append(race)
    
  
X = np.array(sequences)
y = np.array(targets)
race_labels = np.array(race_labels)  

print("X shape:", X.shape)
print("y shape:", y.shape)
print("Example target values:", y[:5])
# Out:
# X shape: (299, 10, 5)
# y shape: (299,)
# Example target values: [ 3. 11. 15. 13.  2.]

# %%
baseline_preds = []

for i in range(len(X)):

    avg_position = X[i,:,3].mean()
    baseline_preds.append(round(avg_position))

baseline_preds = np.array(baseline_preds)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

baseline_mae = mean_absolute_error(y, baseline_preds)
baseline_rmse = np.sqrt(mean_squared_error(y, baseline_preds))

print(f"Baseline MAE  : {baseline_mae:.2f} positions")
print(f"Baseline RMSE : {baseline_rmse:.2f} positions")
# Out:
# Baseline MAE  : 2.66 positions
# Baseline RMSE : 3.91 positions

# %%
from sklearn.preprocessing import StandardScaler

n_samples, n_timesteps, n_features = X.shape

X_reshaped = X.reshape(-1, n_features)

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X_reshaped)

X_scaled = X_scaled.reshape(n_samples, n_timesteps, n_features)

print("X_scaled shape:", X_scaled.shape)
print("Mean per feature:", X_scaled.mean(axis=(0,1)).round(3))
print("Std per feature:", X_scaled.std(axis=(0,1)).round(3))
# Out:
# X_scaled shape: (299, 10, 5)
# Mean per feature: [ 0. -0. -0. -0. -0.]
# Std per feature: [1. 1. 1. 1. 1.]

# %%
test_mask = np.isin(race_labels, test_races)
X_train, X_test = X_scaled[~test_mask], X_scaled[test_mask]
y_train, y_test = y[~test_mask], y[test_mask]

print("Train samples:", len(X_train))
print("Test samples:", len(X_test))
# Out:
# Train samples: 261
# Test samples: 38

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
model = Sequential([
    LSTM(64, return_sequences= True, input_shape = (WINDOW_SIZE, len(feature_cols))),
    Dropout(0.2),
    LSTM(32, return_sequences= False),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(1)
])

model.compile(
    optimizer='adam',
    loss = 'mae',
    metrics= ['mae']
)

model.summary()
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        17,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 10, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 30,881 (120.63 KB)
#  Trainable params: 30,881 (120.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stopping = EarlyStopping(
    monitor = 'val_loss',
    patience = 15,
    restore_best_weights= True
)

history = model.fit(
        X_train, y_train,
    epochs=200,
    batch_size= 16,
    validation_split=0.2,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss:
# Epoch 45/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0772 - mae: 2.0772 - val_loss: 3.1029 - val_mae: 3.1029
# Epoch 46/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9702 - mae: 1.9702 - val_loss: 3.2367 - val_mae: 3.2367
# Epoch 47/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9241 - mae: 1.9241 - val_loss: 2.9136 - val_mae: 2.9136
# Epoch 48/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9162 - mae: 1.9162 - val_loss: 3.2944 - val_mae: 3.2944
# Epoch 49/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8781 - mae: 1.8781 - val_loss: 3.1668 - val_mae: 3.1668
# Epoch 50/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9318 - mae: 1.9318 - val_loss: 3.0948 - val_mae: 3.0948
# Epoch 51/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1105 - mae: 2.1105 - val_loss: 2.9793 - val_mae: 2.9793
# Epoch 52/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7973 - mae: 1.7973 - val_loss: 3.0578 - val_mae: 3.0578
# Epoch 53/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8631 - mae: 1.8631 - val_loss: 3.0701 - val_mae: 3.0701
# Epoch 54/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8517 - mae: 1.8517 - val_loss: 3.1088 - val_mae: 3.1088
# Epoch 55/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9020 - mae: 1.9020 - val_loss: 3.0910 - val_mae: 3.0910
# Epoch 56/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0179 - mae: 2.0179 - val_loss: 3.2444 - val_mae: 3.2444
# Epoch 57/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9581 - mae: 1.9581 - val_loss: 2.9781 - val_mae: 2.9781
# Epoch 58/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9446 - mae: 1.9446 - val_loss: 3.2628 - val_mae: 3.2628
# Epoch 59/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8294 - mae: 1.8294 - val_loss: 2.9962 - val_mae: 2.9962
# Epoch 60/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8129 - mae: 1.8129 - val_loss: 3.1796 - val_mae: 3.1796
# Epoch 61/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8606 - mae: 1.8606 - val_loss: 2.9017 - val_mae: 2.9017
# Epoch 62/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9800 - mae: 1.9800 - val_loss: 3.0445 - val_mae: 3.0445
# Epoch 63/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7372 - mae: 1.7372 - val_loss: 3.2849 - val_mae: 3.2849
# Epoch 64/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9234 - mae: 1.9234 - val_loss: 3.0118 - val_mae: 3.0118
# Epoch 65/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8269 - mae: 1.8269 - val_loss: 3.1656 - val_mae: 3.1656
# Epoch 66/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7476 - mae: 1.7476 - val_loss: 3.1761 - val_mae: 3.1761
# Epoch 67/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8276 - mae: 1.8276 - val_loss: 3.1414 - val_mae: 3.1414
# Epoch 68/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6795 - mae: 1.6795 - val_loss: 3.0371 - val_mae: 3.0371
# Epoch 69/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8512 - mae: 1.8512 - val_loss: 3.0405 - val_mae: 3.0405
# Epoch 70/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7734 - mae: 1.7734 - val_loss: 3.1031 - val_mae: 3.1031
# Epoch 71/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8953 - mae: 1.8953 - val_loss: 3.0354 - val_mae: 3.0354
# Epoch 72/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7746 - mae: 1.7746 - val_loss: 3.0530 - val_mae: 3.0530
# Epoch 73/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6606 - mae: 1.6606 - val_loss: 3.0790 - val_mae: 3.0790
# Epoch 74/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5527 - mae: 1.5527 - val_loss: 3.1728 - val_mae: 3.1728
# Epoch 75/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7540 - mae: 1.7540 - val_loss: 3.1256 - val_mae: 3.1256
# Epoch 76/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7532 - mae: 1.7532 - val_loss: 3.1679 - val_mae: 3.1679

# %%
lstm_preds = model.predict(X_test).flatten()

lstm_preds = np.clip(lstm_preds, 1, 20)

lstm_mae  = mean_absolute_error(y_test, lstm_preds)
lstm_rmse = np.sqrt(mean_squared_error(y_test, lstm_preds))

print(f"Baseline MAE  : 2.66")
print(f"LSTM MAE      : {lstm_mae:.2f}")
print(f"")
print(f"Baseline RMSE : 3.91")
print(f"LSTM RMSE     : {lstm_rmse:.2f}")
print(f"")
print(f"MAE  improvement: {2.66 - lstm_mae:.2f} positions")
print(f"RMSE improvement: {3.91 - lstm_rmse:.2f} positions")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# Baseline MAE  : 2.66
# LSTM MAE      : 3.83
#
# Baseline RMSE : 3.91
# LSTM RMSE     : 5.17
#
# MAE  improvement: -1.17 positions
# RMSE improvement: -1.26 positions

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.axhline(y=2.66, color='red', linestyle='--', label='Baseline MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE (positions)')
plt.title('LSTM Training History')
plt.legend()
plt.tight_layout()
# plt.savefig('assets/training_history.png', dpi=150)
plt.show()
